# %%
#install these packages
# !pip install mlxtend
# !pip install mlxtend pyfpgrowth
# Out:
# Requirement already satisfied: mlxtend in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: mlxtend in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (0.23.1)
# Requirement already satisfied: pyfpgrowth in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (1.0)
# Requirement already satisfied: scipy>=1.2.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/deepeshtomar/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
#import these packages
import itertools
import time
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import pyfpgrowth

# %%
#To read CSV transaction Files
def load_data(fp):
    txns = []
    with open(fp, 'r') as f:
        reader = pd.read_csv(f)
        for _, r in reader.iterrows():
            txns.append(r['Transaction'].split(', '))
    return txns

# %%
#code implementation for Brute force
def brute_force_search(t_data, s_thresh):
    all_items = set(item for transaction in t_data for item in transaction)
    max_itemset_size = len(all_items)
    freq_sets = {}
    for l in range(1, max_itemset_size + 1):
        current_lvl_itemsets = list(itertools.combinations(all_items, l))
        current_lvl_freq = 0
        for itemset in current_lvl_itemsets:
            frequency = sum(1 for transaction in t_data if set(itemset).issubset(set(transaction)))
            if frequency / len(t_data) >= s_thresh:
                freq_sets[itemset] = frequency
                current_lvl_freq += 1
        if current_lvl_freq == 0:
            break
    return freq_sets

# %%
# Converts a list of transactions into a one-hot encoded DataFrame suitable for itemset mining.
def encode_txns(txns):
    encoder = TransactionEncoder()
    encoded_ary = encoder.fit(txns).transform(txns)
    df_encoded = pd.DataFrame(encoded_ary, columns=encoder.columns_)
    return df_encoded

# %%
#code implementation for apriori Algorithm
def apriori_search(t_data, s_thresh):
    df_encoded = encode_txns(t_data)
    freq_itemsets = apriori(df_encoded, min_support=s_thresh, use_colnames=True)
    return freq_itemsets

# %%
#code implementation for FP-Growth Algorithm
def fpgrowth_search(t_data, s_thresh):
    min_count = int(s_thresh * len(t_data))
    patterns = pyfpgrowth.find_frequent_patterns(t_data, min_count)
    # Constructing the DataFrame with frozenset itemsets and support
    freq_sets = pd.DataFrame([(frozenset(k), v / len(t_data)) for k, v in patterns.items()], columns=['itemsets', 'support'])
    return freq_sets

# %%
def generate_assoc_rules(freq_sets, t_data, c_thresh):
    # No need for `support_only=True` if the DataFrame is structured correctly.
    if not freq_sets.empty:
        rules = association_rules(freq_sets, metric="confidence", min_threshold=c_thresh, support_only = True)
        return rules[['antecedents', 'consequents', 'support', 'confidence']]
    return pd.DataFrame()

# %%
# Compares the performance and output of Brute Force, Apriori, and FP-Growth algorithms on given transaction data.
def algo_comparison(fp, s_thresh, c_thresh):
    t_data = load_data(fp)
    
    # Brute Force
    t_start = time.time()
    bf_sets = brute_force_search(t_data, s_thresh)
    t_bf = time.time() - t_start
    print(bf_sets)
    # Apriori
    t_start = time.time()
    ap_sets = apriori_search(t_data, s_thresh)
    t_ap = time.time() - t_start
    ap_rules = generate_assoc_rules(ap_sets, t_data, c_thresh)
    print(ap_sets)
    # FP-Growth
    t_start = time.time()
    fp_sets = fpgrowth_search(t_data, s_thresh)
    t_fp = time.time() - t_start
    fp_rules = generate_assoc_rules(fp_sets, t_data, c_thresh)
    print(fp_sets)
    # Determine the fastest algorithm
    fastest_time = min(t_bf, t_ap, t_fp)
    fastest_algo = 'Brute Force' if fastest_time == t_bf else ('Apriori' if fastest_time == t_ap else 'FP-Growth')
    
    print(f"Brute Force: {len(bf_sets)} sets in {t_bf:.5f} sec.")
    print(f"Apriori: {len(ap_sets)} sets, {len(ap_rules)} rules in {t_ap:.5f} sec.")
    print(f"FP-Growth: {len(fp_sets)} sets, {len(fp_rules)} rules in {t_fp:.5f} sec.")
    print(f"The fastest algorithm for {fp} is {fastest_algo} with a time of {fastest_time:.5f} sec.\n")
    
    return bf_sets, ap_rules, fp_rules

# %%
def main():
    s_thresh = float(input("Support (fraction): "))
    c_thresh = float(input("Confidence (fraction): "))
    fps = ['Amazon.csv', 'Best_Buy.csv', 'Generic.csv', 'K-Mart.csv', 'Nike.csv']
    for fp in fps:
        print(f"Processing {fp}")
        _, ap_rules, fp_rules = algo_comparison(fp, s_thresh, c_thresh)
        print(f"AP: {len(ap_rules)} rules, FP: {len(fp_rules)} rules\n")

if __name__ == "__main__":
    main()
# Out:
# Support (fraction): 0.5
# Confidence (fraction): 0.5
# Processing Amazon.csv
# {('Java: The Complete Reference',): 10, ('Java For Dummies',): 13, ('Android Programming: The Big Nerd Ranch',): 12, ("A Beginner's Guide",): 11, ('Java: The Complete Reference', 'Java For Dummies'): 10}
#    support                                          itemsets
# 0     0.55                              (A Beginner's Guide)
# 1     0.60         (Android Programming: The Big Nerd Ranch)
# 2     0.65                                (Java For Dummies)
# 3     0.50                    (Java: The Complete Reference)
# 4     0.50  (Java: The Complete Reference, Java For Dummies)
#                                            itemsets  support
# 0                    (Java: The Complete Reference)     0.50
# 1  (Java: The Complete Reference, Java For Dummies)     0.50
# 2                              (A Beginner's Guide)     0.55
# 3         (Android Programming: The Big Nerd Ranch)     0.60
# 4                                (Java For Dummies)     0.65
# Brute Force: 5 sets in 0.00216 sec.
# Apriori: 5 sets, 2 rules in 0.00502 sec.
# FP-Growth: 5 sets, 2 rules in 0.00049 sec.
# The fastest algorithm for Amazon.csv is FP-Growth with a time of 0.00049 sec.
#
# AP: 2 rules, FP: 2 rules
#
# Processing Best_Buy.csv
# {('Flash Drive',): 11, ('Anti-Virus',): 12, ('Printer',): 10, ('Lab Top Case',): 13, ('Lab Top',): 12, ('Speakers',): 11, ('Anti-Virus', 'Lab Top Case'): 10}
#    support                    itemsets
# 0     0.60                (Anti-Virus)
# 1     0.55               (Flash Drive)
# 2     0.60                   (Lab Top)
# 3     0.65              (Lab Top Case)
# 4     0.50                   (Printer)
# 5     0.55                  (Speakers)
# 6     0.50  (Lab Top Case, Anti-Virus)
#                      itemsets  support
# 0                   (Printer)     0.50
# 1               (Flash Drive)     0.55
# 2                  (Speakers)     0.55
# 3                (Anti-Virus)     0.60
# 4  (Lab Top Case, Anti-Virus)     0.50
# 5                   (Lab Top)     0.60
# 6              (Lab Top Case)     0.65
# Brute Force: 7 sets in 0.00890 sec.
# Apriori: 7 sets, 2 rules in 0.00186 sec.
# FP-Growth: 7 sets, 2 rules in 0.00032 sec.
# The fastest algorithm for Best_Buy.csv is FP-Growth with a time of 0.00032 sec.
#
# AP: 2 rules, FP: 2 rules
#
# Processing Generic.csv
# {('C',): 7, ('E',): 8, ('A',): 11, ('C', 'A'): 7, ('E', 'A'): 8}
#     support itemsets
# 0  1.000000      (A)
# 1  0.636364      (C)
# 2  0.727273      (E)
# 3  0.636364   (C, A)
# 4  0.727273   (A, E)
#   itemsets   support
# 0      (B)  0.454545
# 1   (B, A)  0.454545
# 2      (C)  0.636364
# 3   (C, A)  0.636364
# 4      (E)  0.727273
# 5   (A, E)  0.727273
# 6      (A)  1.000000
# Brute Force: 5 sets in 0.00009 sec.
# Apriori: 5 sets, 4 rules in 0.00137 sec.
# FP-Growth: 7 sets, 4 rules in 0.00019 sec.
# The fastest algorithm for Generic.csv is Brute Force with a time of 0.00009 sec.
#
# AP: 4 rules, FP: 4 rules
#
# Processing K-Mart.csv
# {('Shams',): 11}
#    support itemsets
# 0     0.55  (Shams)
#   itemsets  support
# 0  (Shams)     0.55
# Brute Force: 1 sets in 0.00126 sec.
# Apriori: 1 sets, 0 rules in 0.00083 sec.
# FP-Growth: 1 sets, 0 rules in 0.00012 sec.
# The fastest algorithm for K-Mart.csv is FP-Growth with a time of 0.00012 sec.
#
# AP: 0 rules, FP: 0 rules
#
# Processing Nike.csv
# {('Sweatshirts',): 13, ('Running Shoe',): 14, ('Rash Guard',): 12, ('Socks',): 13, ('Swimming Shirt',): 11, ('Modern Pants',): 10, ('Sweatshirts', 'Running Shoe'): 11, ('Sweatshirts', 'Socks'): 12, ('Sweatshirts', 'Modern Pants'): 10, ('Running Shoe', 'Socks'): 11, ('Rash Guard', 'Swimming Shirt'): 10, ('Sweatshirts', 'Running Shoe', 'Socks'): 10}
#     support                            itemsets
# 0      0.50                      (Modern Pants)
# 1      0.60                        (Rash Guard)
# 2      0.70                      (Running Shoe)
# 3      0.65                             (Socks)
# 4      0.65                       (Sweatshirts)
# 5      0.55                    (Swimming Shirt)
# 6      0.50         (Sweatshirts, Modern Pants)
# 7      0.50        (Swimming Shirt, Rash Guard)
# 8      0.55               (Socks, Running Shoe)
# 9      0.55         (Sweatshirts, Running Shoe)
# 10     0.60                (Socks, Sweatshirts)
# 11     0.50  (Socks, Sweatshirts, Running Shoe)
#                               itemsets  support
# 0                       (Modern Pants)     0.50
# 1          (Sweatshirts, Modern Pants)     0.50
# 2                     (Swimming Shirt)     0.55
# 3         (Swimming Shirt, Rash Guard)     0.50
# 4                         (Rash Guard)     0.60
# 5                              (Socks)     0.65
# 6                (Socks, Running Shoe)     0.55
# 7          (Sweatshirts, Running Shoe)     0.55
# 8   (Socks, Sweatshirts, Running Shoe)     0.50
# 9                 (Socks, Sweatshirts)     0.60
# 10                      (Running Shoe)     0.70
# Brute Force: 12 sets in 0.00608 sec.
# Apriori: 12 sets, 16 rules in 0.00126 sec.
# FP-Growth: 11 sets, 16 rules in 0.00023 sec.
# The fastest algorithm for Nike.csv is FP-Growth with a time of 0.00023 sec.
#
# AP: 16 rules, FP: 16 rules
